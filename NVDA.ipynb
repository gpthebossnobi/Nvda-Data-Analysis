# %% [markdown]
# nvda

# %%
import pandas as pd
import pickle
import warnings

warnings.filterwarnings("ignore")

# %%
nvda = pd.read_csv("/content/sample_data/NVDA.csv")
nvda
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2000-01-03    0.984375    0.992188    0.919271    0.975260    0.894608
# 1     2000-01-04    0.958333    0.960938    0.901042    0.949219    0.870721
# 2     2000-01-05    0.921875    0.937500    0.904948    0.917969    0.842055
# 3     2000-01-06    0.917969    0.917969    0.822917    0.858073    0.787112
# 4     2000-01-07    0.854167    0.881510    0.841146    0.872396    0.800251
# ...          ...         ...         ...         ...         ...         ...
# 6111  2024-04-18  849.700012  861.900024  824.020020  846.710022  846.710022
# 6112  2024-04-19  831.500000  843.239990  756.059998  762.000000  762.000000
# 6113  2024-04-22  781.039978  800.729980  764.000000  795.179993  795.179993
# 6114  2024-04-23  807.690002  827.690002  802.640015  824.229980  824.229980
# 6115  2024-04-24  839.500000  840.820007  791.830017  796.770020  796.770020
#
#         Volume
# 0     30091200
# ...

# %%
print(type(nvda))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
nvda.shape
# Out:
# (6116, 7)

# %%
nvda.head(11)
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume
# 0   2000-01-03  0.984375  0.992188  0.919271  0.975260   0.894608  30091200
# 1   2000-01-04  0.958333  0.960938  0.901042  0.949219   0.870721  30048000
# 2   2000-01-05  0.921875  0.937500  0.904948  0.917969   0.842055  18835200
# 3   2000-01-06  0.917969  0.917969  0.822917  0.858073   0.787112  12048000
# 4   2000-01-07  0.854167  0.881510  0.841146  0.872396   0.800251   7118400
# 5   2000-01-10  0.875000  0.937500  0.859375  0.901042   0.826528  23985600
# 6   2000-01-11  0.895833  0.906250  0.864583  0.864583   0.793084  14812800
# 7   2000-01-12  0.864583  0.865885  0.830729  0.842448   0.772779  12355200
# 8   2000-01-13  0.841146  0.885417  0.830729  0.877604   0.805028  13219200
# 9   2000-01-14  0.890625  0.951823  0.888021  0.915365   0.839666  60456000
# 10  2000-01-18  0.927083  0.958333  0.885417  0.954427   0.875498  26164800

# %%
nvda.tail(6)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 6110  2024-04-17  883.400024  887.750000  839.500000  840.349976  840.349976
# 6111  2024-04-18  849.700012  861.900024  824.020020  846.710022  846.710022
# 6112  2024-04-19  831.500000  843.239990  756.059998  762.000000  762.000000
# 6113  2024-04-22  781.039978  800.729980  764.000000  795.179993  795.179993
# 6114  2024-04-23  807.690002  827.690002  802.640015  824.229980  824.229980
# 6115  2024-04-24  839.500000  840.820007  791.830017  796.770020  796.770020
#
#         Volume
# 6110  49540000
# 6111  44726000
# 6112  87190500
# 6113  59634100
# 6114  43855900
# 6115  50961600

# %%
nvda["Open"].unique()
# Out:
# array([  0.984375,   0.958333,   0.921875, ..., 781.039978, 807.690002,
#        839.5     ])

# %%
nvda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6116 entries, 0 to 6115
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6116 non-null   object
#  1   Open       6116 non-null   float64
#  2   High       6116 non-null   float64
#  3   Low        6116 non-null   float64
#  4   Close      6116 non-null   float64
#  5   Adj Close  6116 non-null   float64
#  6   Volume     6116 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 334.6+ KB

# %%
nvda.groupby(["Volume"]).count()
# Out:
#            Date  Open  High  Low  Close  Adj Close
# Volume
# 4564400       1     1     1    1      1          1
# 5244800       1     1     1    1      1          1
# 5263600       1     1     1    1      1          1
# 7118400       1     1     1    1      1          1
# 7960000       1     1     1    1      1          1
# ...         ...   ...   ...  ...    ...        ...
# 429282000     1     1     1    1      1          1
# 483714000     1     1     1    1      1          1
# 508894800     1     1     1    1      1          1
# 513547200     1     1     1    1      1          1
# 923085600     1     1     1    1      1          1
#
# [6040 rows x 6 columns]

# %%
nvda.groupby(["High"]).count()
# Out:
#             Date  Open  Low  Close  Adj Close  Volume
# High
# 0.656667       1     1    1      1          1       1
# 0.665833       1     1    1      1          1       1
# 0.668333       1     1    1      1          1       1
# 0.682500       1     1    1      1          1       1
# 0.734167       1     1    1      1          1       1
# ...          ...   ...  ...    ...        ...     ...
# 932.400024     1     1    1      1          1       1
# 947.780029     1     1    1      1          1       1
# 963.750000     1     1    1      1          1       1
# 967.659973     1     1    1      1          1       1
# 974.000000     1     1    1      1          1       1
#
# [4643 rows x 6 columns]

# %%
nvda["Date"].unique()
# Out:
# array(['2000-01-03', '2000-01-04', '2000-01-05', ..., '2024-04-22',
#        '2024-04-23', '2024-04-24'], dtype=object)
